# %%
# https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
import math
import copy
import random
from dataclasses import dataclass

# %%
from algo.dynamicProgramming import dynamicPlayer
from algo.iplayer import RandomPlayer, IPlayer
from algo.board import Board, GameState

# %%
device = torch.device(
    # "cuda" if torch.cuda.is_available() else
    # "mps" if torch.backends.mps.is_available() else
    "cpu"
)
device
# Out:
# device(type='cpu')

# %%
class DQN(nn.Module):
	"""
	Using structure similar to NNUE:
	https://www.chessprogramming.org/File:StockfishNNUELayers.png
	
	Observation space: hot-encoded board:
	for each of 18 cells we can be -2, -1, 0, 1, 2 (5 possibilities).
	In total it gives 18 * 5 = 90 possible inputs, out of which at most 12 are on.
	
	# Action space: 4 possible actions.
	Value function: 1 output. # https://www.reddit.com/r/reinforcementlearning/comments/1b1te73/help_me_understand_why_use_a_policy_net_instead/
	"""

	def __init__(self, layer_sizes: list[int]) -> None:
		super(DQN, self).__init__()

		layers = []
		prev_size = layer_sizes[0]
		for cur_size in layer_sizes[1:]:
			layers.append(nn.Linear(prev_size, cur_size))
			prev_size = cur_size

		self.layers = nn.ModuleList(layers)

	def forward(self, board: Board) -> torch.Tensor:
		state = board.to_tensor(device)
		for layer in self.layers[:-1]:
			state = F.relu(layer(state))
		return self.layers[-1](state)

# %%
def make_environment_step(state: Board, action: tuple[tuple[int, int], tuple[int, int]], enemy: IPlayer) -> tuple[Board, torch.Tensor]:
	"""
	Returns new state and reward for the given action.
	"""
	state = copy.deepcopy(state)
	cur_sign = state.turn_sign
	we_captured = state.make_move(*action) * cur_sign
	enemy_captured = 0
	while state.game_state == GameState.NOT_OVER and state.turn_sign != cur_sign:
		enemy_captured += state.make_move(*enemy.decide_move(state)) * cur_sign * (-1)
		
	reward = we_captured - enemy_captured
	if state.game_state != GameState.NOT_OVER:
		our_pieces = 0
		enemy_pieces = 0
		for _, piece in state:
			if piece == cur_sign:
				our_pieces += 1
			elif piece == -cur_sign:
				enemy_pieces += 1
			elif piece == 2 * cur_sign:
				our_pieces += 2
			elif piece == -2 * cur_sign:
				enemy_pieces += 2
			
		reward += 3 * our_pieces / (enemy_pieces + 1)

		if state.game_state == GameState.DRAW:
			reward -= 40
		elif state.game_state == GameState(cur_sign):
			reward += 40
		elif state.game_state == GameState(-cur_sign):
			reward -= 40
		else:
			raise ValueError("Unexpected game state")
	
	return state, torch.Tensor([reward])

# %%
GAMMA = 0.99 # discount rate

@dataclass
class Action:
	action: tuple[tuple[int, int], tuple[int, int]]
	value: torch.Tensor

def q_s(dqn: DQN, current_state: Board) -> list[Action]:
	"""
	Return: list[(new_state, action, immediate_reward, value)]
	"""
	ret: list[Action] = []
	for s in current_state.get_possible_pos():
		for e in current_state.get_correct_moves(s):
			next_state = copy.deepcopy(current_state)
			immediate_reward = torch.tensor([next_state.make_move(s, e) * next_state.turn_sign], device=device)
			value = dqn(next_state) * GAMMA + immediate_reward
			ret.append(Action((s, e), value))
	return ret

# %%
BATCH_SIZE = 128 # number of transitions sampled from the replay buffer

EPS_START = 0.9 # exploration rate
EPS_END = 0.05
EPS_DECAY = 1000
TAU = 0.005 # update rate
LR = 1e-4 # AdamW learning rate

policy_net = DQN().to(device) # to be updated often
target_net = DQN().to(device) # to be updated with TAU
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)
steps_done = 0


def select_action(board: Board) -> Action:
	global steps_done
	sample = random.random()
	eps_threshold = EPS_END + (EPS_START - EPS_END) * \
		math.exp(-1. * steps_done / EPS_DECAY)
	steps_done += 1
	if sample > eps_threshold:
		with torch.no_grad():
			state_values = q_s(policy_net, board)
			return max(state_values, key=lambda x: x.value.item())
					
	else:
		possible_moves = []
		for s in board.get_possible_pos():
			for e in board.get_correct_moves(s):
				possible_moves.append((s, e))
		return Action(
			random.choice(possible_moves),
			torch.tensor([0], device=device)
		)

# %%
@dataclass
class TransitionRecord:
	current_state: Board
	next_state: Board
	immediate_reward: torch.Tensor

def optimize_model(memory: list[TransitionRecord]):
	if len(memory) < BATCH_SIZE:
		return
	
	state_action_values = []
	expected_state_action_values = []

	for r in random.sample(memory, BATCH_SIZE):
		# Compute Q(s_t, a) - the model computes Q(s_t), then we select the
		# columns of actions taken. These are the actions which would've been taken
		# for each batch state according to policy_net
		state_action_values.append(max(q_s(policy_net, r.current_state), key=lambda x: x.value.item()).value)

		# Compute V(s_{t+1}) for all next states.
		# Expected values of actions for non_final_next_states are computed based
		# on the "older" target_net; selecting their best reward with max(1).values
		# This is merged based on the mask, such that we'll have either the expected
		# state value or 0 in case the state was final.
		next_state_value = 0
		if r.next_state.game_state == GameState.NOT_OVER:
			with torch.no_grad():
				next_state_value = max(q_s(target_net, r.next_state), key=lambda x: x.value.item()).value
		# Compute the expected Q values
		expected_state_action_values.append((next_state_value * GAMMA) + r.immediate_reward)

	# Compute Huber loss
	criterion = nn.SmoothL1Loss()
	loss = criterion(
		torch.cat(state_action_values),
		torch.cat(expected_state_action_values)
	)

	# Optimize the model
	optimizer.zero_grad()
	loss.backward()
	# In-place gradient clipping
	torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
	optimizer.step()

# %%
if torch.cuda.is_available() or torch.backends.mps.is_available():
	num_episodes = 600
else:
	num_episodes = 50
	
memory: list[TransitionRecord] = []

win_rate = []

enemy = RandomPlayer(0)

for i_episode in range(num_episodes):
	# Initialize the environment and get its state
	cur_state = Board()

	if i_episode % 2 == 0:
		our_sign = -1
		cur_state.make_move(*enemy.decide_move(cur_state))
	else:
		our_sign = 1
	
	while True:
		action = select_action(cur_state)
		new_state, immediate_reward = make_environment_step(cur_state, action.action, enemy)

		memory.append(TransitionRecord(cur_state, new_state, torch.tensor([immediate_reward], device=device)))
		cur_state = new_state

		if cur_state.game_state != GameState.NOT_OVER:
			win_rate.append(cur_state.game_state == GameState(our_sign))
			break

	# Perform one step of the optimization (on the policy network)
	optimize_model(memory)

	# Soft update of the target network's weights
	# θ′ ← τ θ + (1 −τ )θ′
	target_net_state_dict = target_net.state_dict()
	policy_net_state_dict = policy_net.state_dict()
	for key in policy_net_state_dict:
		target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
	target_net.load_state_dict(target_net_state_dict)

	print(f"Episode {i_episode} finished. {sum(win_rate[-20:])}/{20}")

print('Complete')
# Out:
# Episode 0 finished. 1/20
# Episode 1 finished. 1/20
# Episode 2 finished. 1/20
# Episode 3 finished. 2/20
# Episode 4 finished. 2/20
# Episode 5 finished. 3/20
# Episode 6 finished. 3/20
# Episode 7 finished. 3/20
# Episode 8 finished. 3/20
# Episode 9 finished. 3/20
# Episode 10 finished. 3/20
# Episode 11 finished. 3/20
# Episode 12 finished. 4/20
# Episode 13 finished. 4/20
# Episode 14 finished. 4/20
# Episode 15 finished. 4/20
# Episode 16 finished. 4/20
# Episode 17 finished. 4/20
# Episode 18 finished. 5/20
# Episode 19 finished. 6/20
# Episode 20 finished. 6/20
# Episode 21 finished. 6/20
# Episode 22 finished. 6/20
# Episode 23 finished. 6/20
# Episode 24 finished. 7/20
# Episode 25 finished. 7/20
# Episode 26 finished. 8/20
# Episode 27 finished. 9/20
# Episode 28 finished. 9/20
# Episode 29 finished. 10/20
# Episode 30 finished. 11/20
# Episode 31 finished. 11/20
# Episode 32 finished. 11/20
# Episode 33 finished. 11/20
# Episode 34 finished. 12/20
# Episode 35 finished. 12/20
# Episode 36 finished. 13/20
# Episode 37 finished. 14/20
# Episode 38 finished. 13/20
# Episode 39 finished. 12/20
# Episode 40 finished. 12/20
# Episode 41 finished. 12/20
# Episode 42 finished. 12/20
# Episode 43 finished. 11/20
# Episode 44 finished. 11/20
# Episode 45 finished. 10/20
# Episode 46 finished. 10/20
# Episode 47 finished. 9/20
# Episode 48 finished. 9/20
# Episode 49 finished. 9/20
# Episode 50 finished. 9/20
# Episode 51 finished. 9/20
# Episode 52 finished. 8/20
# Episode 53 finished. 8/20
# Episode 54 finished. 8/20
# Episode 55 finished. 8/20
# Episode 56 finished. 7/20
# Episode 57 finished. 6/20
# Episode 58 finished. 6/20
# Episode 59 finished. 6/20
# Episode 60 finished. 6/20
# Episode 61 finished. 6/20
# Episode 62 finished. 6/20
# Episode 63 finished. 7/20
# Episode 64 finished. 7/20
# Episode 65 finished. 7/20
# Episode 66 finished. 6/20
# Episode 67 finished. 6/20
# Episode 68 finished. 6/20
# Episode 69 finished. 6/20
# Episode 70 finished. 5/20
# Episode 71 finished. 5/20
# Episode 72 finished. 6/20
# Episode 73 finished. 7/20
# Episode 74 finished. 6/20
# Episode 75 finished. 6/20
# Episode 76 finished. 7/20
# Episode 77 finished. 8/20
# Episode 78 finished. 9/20
# Episode 79 finished. 10/20
# Episode 80 finished. 9/20
# Episode 81 finished. 9/20
# Episode 82 finished. 9/20
# Episode 83 finished. 8/20
# Episode 84 finished. 8/20
# Episode 85 finished. 9/20
# Episode 86 finished. 10/20
# Episode 87 finished. 11/20
# Episode 88 finished. 11/20
# Episode 89 finished. 11/20
# Episode 90 finished. 11/20
# Episode 91 finished. 12/20
# Episode 92 finished. 12/20
# Episode 93 finished. 12/20
# Episode 94 finished. 13/20
# Episode 95 finished. 14/20
# Episode 96 finished. 13/20
# Episode 97 finished. 12/20
# Episode 98 finished. 12/20
# Episode 99 finished. 12/20
# Episode 100 finished. 12/20
# Episode 101 finished. 13/20
# Episode 102 finished. 13/20
# Episode 103 finished. 13/20
# Episode 104 finished. 13/20
# Episode 105 finished. 13/20
# Episode 106 finished. 12/20
# Episode 107 finished. 11/20
# Episode 108 finished. 11/20
# Episode 109 finished. 10/20
# Episode 110 finished. 11/20
# Episode 111 finished. 10/20
# Episode 112 finished. 10/20
# Episode 113 finished. 10/20
# Episode 114 finished. 10/20
# Episode 115 finished. 10/20
# Episode 116 finished. 10/20
# Episode 117 finished. 10/20
# Episode 118 finished. 9/20
# Episode 119 finished. 9/20
# Episode 120 finished. 9/20
# Episode 121 finished. 8/20
# Episode 122 finished. 9/20
# Episode 123 finished. 10/20
# Episode 124 finished. 10/20
# Episode 125 finished. 10/20
# Episode 126 finished. 11/20
# Episode 127 finished. 12/20
# Episode 128 finished. 13/20
# Episode 129 finished. 13/20
# Episode 130 finished. 13/20
# Episode 131 finished. 14/20
# Episode 132 finished. 13/20
# Episode 133 finished. 12/20
# Episode 134 finished. 12/20
# Episode 135 finished. 12/20
# Episode 136 finished. 12/20
# Episode 137 finished. 12/20
# Episode 138 finished. 13/20
# Episode 139 finished. 13/20
# Episode 140 finished. 13/20
# Episode 141 finished. 14/20
# Episode 142 finished. 13/20
# Episode 143 finished. 13/20
# Episode 144 finished. 13/20
# Episode 145 finished. 12/20
# Episode 146 finished. 12/20
# Episode 147 finished. 12/20
# Episode 148 finished. 12/20
# Episode 149 finished. 13/20
# Episode 150 finished. 13/20
# Episode 151 finished. 13/20
# Episode 152 finished. 13/20
# Episode 153 finished. 13/20
# Episode 154 finished. 13/20
# Episode 155 finished. 13/20
# Episode 156 finished. 14/20
# Episode 157 finished. 15/20
# Episode 158 finished. 14/20
# Episode 159 finished. 14/20
# Episode 160 finished. 14/20
# Episode 161 finished. 13/20
# Episode 162 finished. 14/20
# Episode 163 finished. 14/20
# Episode 164 finished. 13/20
# Episode 165 finished. 13/20
# Episode 166 finished. 12/20
# Episode 167 finished. 12/20
# Episode 168 finished. 12/20
# Episode 169 finished. 12/20
# Episode 170 finished. 11/20
# Episode 171 finished. 11/20
# Episode 172 finished. 11/20
# Episode 173 finished. 11/20
# Episode 174 finished. 11/20
# Episode 175 finished. 11/20
# Episode 176 finished. 11/20
# Episode 177 finished. 11/20
# Episode 178 finished. 11/20
# Episode 179 finished. 10/20
# Episode 180 finished. 11/20
# Episode 181 finished. 12/20
# Episode 182 finished. 12/20
# Episode 183 finished. 11/20
# Episode 184 finished. 12/20
# Episode 185 finished. 12/20
# Episode 186 finished. 13/20
# Episode 187 finished. 13/20
# Episode 188 finished. 13/20
# Episode 189 finished. 13/20
# Episode 190 finished. 13/20
# Episode 191 finished. 13/20
# Episode 192 finished. 13/20
# Episode 193 finished. 14/20
# Episode 194 finished. 14/20
# Episode 195 finished. 13/20
# Episode 196 finished. 12/20
# Episode 197 finished. 12/20
# Episode 198 finished. 13/20
# Episode 199 finished. 14/20
# Episode 200 finished. 14/20
# Episode 201 finished. 14/20
# Episode 202 finished. 14/20
# Episode 203 finished. 14/20
# Episode 204 finished. 14/20
# Episode 205 finished. 15/20
# Episode 206 finished. 15/20
# Episode 207 finished. 15/20
# Episode 208 finished. 15/20
# Episode 209 finished. 15/20
# Episode 210 finished. 16/20
# Episode 211 finished. 16/20
# Episode 212 finished. 17/20
# Episode 213 finished. 17/20
# Episode 214 finished. 17/20
# Episode 215 finished. 17/20
# Episode 216 finished. 18/20
# Episode 217 finished. 17/20
# Episode 218 finished. 16/20
# Episode 219 finished. 15/20
# Episode 220 finished. 14/20
# Episode 221 finished. 13/20
# Episode 222 finished. 13/20
# Episode 223 finished. 14/20
# Episode 224 finished. 14/20
# Episode 225 finished. 13/20
# Episode 226 finished. 13/20
# Episode 227 finished. 13/20
# Episode 228 finished. 13/20
# Episode 229 finished. 13/20
# Episode 230 finished. 13/20
# Episode 231 finished. 13/20
# Episode 232 finished. 12/20
# Episode 233 finished. 11/20
# Episode 234 finished. 11/20
# Episode 235 finished. 12/20
# Episode 236 finished. 11/20
# Episode 237 finished. 12/20
# Episode 238 finished. 13/20
# Episode 239 finished. 14/20
# Episode 240 finished. 14/20
# Episode 241 finished. 15/20
# Episode 242 finished. 15/20
# Episode 243 finished. 15/20
# Episode 244 finished. 14/20
# Episode 245 finished. 15/20
# Episode 246 finished. 15/20
# Episode 247 finished. 15/20
# Episode 248 finished. 15/20
# Episode 249 finished. 14/20
# Episode 250 finished. 14/20
# Episode 251 finished. 14/20
# Episode 252 finished. 14/20
# Episode 253 finished. 15/20
# Episode 254 finished. 14/20
# Episode 255 finished. 14/20
# Episode 256 finished. 15/20
# Episode 257 finished. 15/20
# Episode 258 finished. 15/20
# Episode 259 finished. 15/20
# Episode 260 finished. 16/20
# Episode 261 finished. 16/20
# Episode 262 finished. 15/20
# Episode 263 finished. 15/20
# Episode 264 finished. 16/20
# Episode 265 finished. 16/20
# Episode 266 finished. 16/20
# Episode 267 finished. 15/20
# Episode 268 finished. 15/20
# Episode 269 finished. 16/20
# Episode 270 finished. 16/20
# Episode 271 finished. 15/20
# Episode 272 finished. 16/20
# Episode 273 finished. 15/20
# Episode 274 finished. 16/20
# Episode 275 finished. 16/20
# Episode 276 finished. 15/20
# Episode 277 finished. 15/20
# Episode 278 finished. 14/20
# Episode 279 finished. 14/20
# Episode 280 finished. 13/20
# Episode 281 finished. 12/20
# Episode 282 finished. 13/20
# Episode 283 finished. 13/20
# Episode 284 finished. 13/20
# Episode 285 finished. 12/20
# Episode 286 finished. 12/20
# Episode 287 finished. 13/20
# Episode 288 finished. 13/20
# Episode 289 finished. 13/20
# Episode 290 finished. 13/20
# Episode 291 finished. 13/20
# Episode 292 finished. 13/20
# Episode 293 finished. 14/20
# Episode 294 finished. 13/20
# Episode 295 finished. 13/20
# Episode 296 finished. 14/20
# Episode 297 finished. 14/20
# Episode 298 finished. 14/20
# Episode 299 finished. 13/20
# Episode 300 finished. 14/20
# Episode 301 finished. 14/20
# Episode 302 finished. 14/20
# Episode 303 finished. 13/20
# Episode 304 finished. 13/20
# Episode 305 finished. 13/20
# Episode 306 finished. 12/20
# Episode 307 finished. 12/20
# Episode 308 finished. 12/20
# Episode 309 finished. 11/20
# Episode 310 finished. 11/20
# Episode 311 finished. 11/20
# Episode 312 finished. 10/20
# Episode 313 finished. 10/20
# Episode 314 finished. 11/20
# Episode 315 finished. 11/20
# Episode 316 finished. 11/20
# Episode 317 finished. 11/20
# Episode 318 finished. 11/20
# Episode 319 finished. 11/20
# Episode 320 finished. 11/20
# Episode 321 finished. 11/20
# Episode 322 finished. 10/20
# Episode 323 finished. 10/20
# Episode 324 finished. 9/20
# Episode 325 finished. 10/20
# Episode 326 finished. 11/20
# Episode 327 finished. 11/20
# Episode 328 finished. 10/20
# Episode 329 finished. 11/20
# Episode 330 finished. 11/20
# Episode 331 finished. 11/20
# Episode 332 finished. 11/20
# Episode 333 finished. 11/20
# Episode 334 finished. 11/20
# Episode 335 finished. 11/20
# Episode 336 finished. 10/20
# Episode 337 finished. 10/20
# Episode 338 finished. 11/20
# Episode 339 finished. 12/20
# Episode 340 finished. 12/20
# Episode 341 finished. 13/20
# Episode 342 finished. 14/20
# Episode 343 finished. 14/20
# Episode 344 finished. 14/20
# Episode 345 finished. 14/20
# Episode 346 finished. 14/20
# Episode 347 finished. 13/20
# Episode 348 finished. 13/20
# Episode 349 finished. 12/20
# Episode 350 finished. 12/20
# Episode 351 finished. 13/20
# Episode 352 finished. 14/20
# Episode 353 finished. 14/20
# Episode 354 finished. 14/20
# Episode 355 finished. 14/20
# Episode 356 finished. 15/20
# Episode 357 finished. 15/20
# Episode 358 finished. 15/20
# Episode 359 finished. 14/20
# Episode 360 finished. 14/20
# Episode 361 finished. 13/20
# Episode 362 finished. 12/20
# Episode 363 finished. 13/20
# Episode 364 finished. 14/20
# Episode 365 finished. 14/20
# Episode 366 finished. 14/20
# Episode 367 finished. 14/20
# Episode 368 finished. 15/20
# Episode 369 finished. 16/20
# Episode 370 finished. 16/20
# Episode 371 finished. 15/20
# Episode 372 finished. 15/20
# Episode 373 finished. 15/20
# Episode 374 finished. 15/20
# Episode 375 finished. 15/20
# Episode 376 finished. 15/20
# Episode 377 finished. 15/20
# Episode 378 finished. 15/20
# Episode 379 finished. 15/20
# Episode 380 finished. 15/20
# Episode 381 finished. 16/20
# Episode 382 finished. 17/20
# Episode 383 finished. 17/20
# Episode 384 finished. 17/20
# Episode 385 finished. 16/20
# Episode 386 finished. 16/20
# Episode 387 finished. 16/20
# Episode 388 finished. 16/20
# Episode 389 finished. 15/20
# Episode 390 finished. 15/20
# Episode 391 finished. 15/20
# Episode 392 finished. 15/20
# Episode 393 finished. 14/20
# Episode 394 finished. 14/20
# Episode 395 finished. 14/20
# Episode 396 finished. 14/20
# Episode 397 finished. 13/20
# Episode 398 finished. 13/20
# Episode 399 finished. 14/20
# Episode 400 finished. 14/20
# Episode 401 finished. 14/20
# Episode 402 finished. 14/20
# Episode 403 finished. 13/20
# Episode 404 finished. 13/20
# Episode 405 finished. 13/20
# Episode 406 finished. 13/20
# Episode 407 finished. 14/20
# Episode 408 finished. 14/20
# Episode 409 finished. 15/20
# Episode 410 finished. 15/20
# Episode 411 finished. 16/20
# Episode 412 finished. 16/20
# Episode 413 finished. 16/20
# Episode 414 finished. 15/20
# Episode 415 finished. 15/20
# Episode 416 finished. 15/20
# Episode 417 finished. 16/20
# Episode 418 finished. 15/20
# Episode 419 finished. 15/20
# Episode 420 finished. 15/20
# Episode 421 finished. 14/20
# Episode 422 finished. 14/20
# Episode 423 finished. 15/20
# Episode 424 finished. 15/20
# Episode 425 finished. 15/20
# Episode 426 finished. 15/20
# Episode 427 finished. 14/20
# Episode 428 finished. 14/20
# Episode 429 finished. 14/20
# Episode 430 finished. 13/20
# Episode 431 finished. 12/20
# Episode 432 finished. 12/20
# Episode 433 finished. 12/20
# Episode 434 finished. 13/20
# Episode 435 finished. 13/20
# Episode 436 finished. 13/20
# Episode 437 finished. 13/20
# Episode 438 finished. 14/20
# Episode 439 finished. 14/20
# Episode 440 finished. 14/20
# Episode 441 finished. 15/20
# Episode 442 finished. 14/20
# Episode 443 finished. 13/20
# Episode 444 finished. 12/20
# Episode 445 finished. 13/20
# Episode 446 finished. 12/20
# Episode 447 finished. 13/20
# Episode 448 finished. 13/20
# Episode 449 finished. 12/20
# Episode 450 finished. 13/20
# Episode 451 finished. 14/20
# Episode 452 finished. 14/20
# Episode 453 finished. 15/20
# Episode 454 finished. 15/20
# Episode 455 finished. 15/20
# Episode 456 finished. 15/20
# Episode 457 finished. 14/20
# Episode 458 finished. 14/20
# Episode 459 finished. 14/20
# Episode 460 finished. 13/20
# Episode 461 finished. 13/20
# Episode 462 finished. 13/20
# Episode 463 finished. 13/20
# Episode 464 finished. 14/20
# Episode 465 finished. 14/20
# Episode 466 finished. 15/20
# Episode 467 finished. 15/20
# Episode 468 finished. 15/20
# Episode 469 finished. 15/20
# Episode 470 finished. 15/20
# Episode 471 finished. 15/20
# Episode 472 finished. 15/20
# Episode 473 finished. 15/20
# Episode 474 finished. 15/20
# Episode 475 finished. 15/20
# Episode 476 finished. 15/20
# Episode 477 finished. 15/20
# Episode 478 finished. 15/20
# Episode 479 finished. 15/20
# Episode 480 finished. 16/20
# Episode 481 finished. 16/20
# Episode 482 finished. 17/20
# Episode 483 finished. 17/20
# Episode 484 finished. 16/20
# Episode 485 finished. 16/20
# Episode 486 finished. 16/20
# Episode 487 finished. 15/20
# Episode 488 finished. 15/20
# Episode 489 finished. 16/20
# Episode 490 finished. 15/20
# Episode 491 finished. 15/20
# Episode 492 finished. 15/20
# Episode 493 finished. 14/20
# Episode 494 finished. 14/20
# Episode 495 finished. 13/20
# Episode 496 finished. 13/20
# Episode 497 finished. 14/20
# Episode 498 finished. 13/20
# Episode 499 finished. 12/20
# Episode 500 finished. 12/20
# Episode 501 finished. 12/20
# Episode 502 finished. 12/20
# Episode 503 finished. 12/20
# Episode 504 finished. 12/20
# Episode 505 finished. 11/20
# Episode 506 finished. 11/20
# Episode 507 finished. 12/20
# Episode 508 finished. 12/20
# Episode 509 finished. 12/20
# Episode 510 finished. 13/20
# Episode 511 finished. 13/20
# Episode 512 finished. 12/20
# Episode 513 finished. 13/20
# Episode 514 finished. 12/20
# Episode 515 finished. 13/20
# Episode 516 finished. 13/20
# Episode 517 finished. 13/20
# Episode 518 finished. 14/20
# Episode 519 finished. 14/20
# Episode 520 finished. 14/20
# Episode 521 finished. 13/20
# Episode 522 finished. 13/20
# Episode 523 finished. 13/20
# Episode 524 finished. 13/20
# Episode 525 finished. 13/20
# Episode 526 finished. 13/20
# Episode 527 finished. 13/20
# Episode 528 finished. 13/20
# Episode 529 finished. 12/20
# Episode 530 finished. 11/20
# Episode 531 finished. 10/20
# Episode 532 finished. 11/20
# Episode 533 finished. 10/20
# Episode 534 finished. 11/20
# Episode 535 finished. 11/20
# Episode 536 finished. 11/20
# Episode 537 finished. 11/20
# Episode 538 finished. 11/20
# Episode 539 finished. 12/20
# Episode 540 finished. 12/20
# Episode 541 finished. 12/20
# Episode 542 finished. 12/20
# Episode 543 finished. 13/20
# Episode 544 finished. 14/20
# Episode 545 finished. 15/20
# Episode 546 finished. 15/20
# Episode 547 finished. 15/20
# Episode 548 finished. 15/20
# Episode 549 finished. 15/20
# Episode 550 finished. 16/20
# Episode 551 finished. 17/20
# Episode 552 finished. 17/20
# Episode 553 finished. 18/20
# Episode 554 finished. 18/20
# Episode 555 finished. 18/20
# Episode 556 finished. 18/20
# Episode 557 finished. 18/20
# Episode 558 finished. 18/20
# Episode 559 finished. 17/20
# Episode 560 finished. 17/20
# Episode 561 finished. 17/20
# Episode 562 finished. 17/20
# Episode 563 finished. 17/20
# Episode 564 finished. 16/20
# Episode 565 finished. 16/20
# Episode 566 finished. 16/20
# Episode 567 finished. 15/20
# Episode 568 finished. 14/20
# Episode 569 finished. 14/20
# Episode 570 finished. 14/20
# Episode 571 finished. 14/20
# Episode 572 finished. 14/20
# Episode 573 finished. 13/20
# Episode 574 finished. 13/20
# Episode 575 finished. 13/20
# Episode 576 finished. 13/20
# Episode 577 finished. 13/20
# Episode 578 finished. 12/20
# Episode 579 finished. 12/20
# Episode 580 finished. 12/20
# Episode 581 finished. 12/20
# Episode 582 finished. 11/20
# Episode 583 finished. 11/20
# Episode 584 finished. 12/20
# Episode 585 finished. 12/20
# Episode 586 finished. 12/20
# Episode 587 finished. 12/20
# Episode 588 finished. 13/20
# Episode 589 finished. 14/20
# Episode 590 finished. 14/20
# Episode 591 finished. 14/20
# Episode 592 finished. 14/20
# Episode 593 finished. 15/20
# Episode 594 finished. 15/20
# Episode 595 finished. 15/20
# Episode 596 finished. 15/20
# Episode 597 finished. 14/20
# Episode 598 finished. 15/20
# Episode 599 finished. 16/20
# Complete

# %%
sum(win_rate) / len(win_rate)
# Out:
# 0.64

# %%
len(win_rate)
# Out:
# 600

# %%
sum(win_rate)
# Out:
# 384

# %%
stats = []

enemy = RandomPlayer(random.randint(0, 10000))

for i in range(10000):
	board = Board()
	while board.game_state == GameState.NOT_OVER:
		while board.game_state == GameState.NOT_OVER and board.turn_sign == 1:
			board.make_move(*enemy.decide_move(board))
		while board.game_state == GameState.NOT_OVER and board.turn_sign == -1:
			with torch.no_grad():
				state_values = max(q_s(target_net, board), key=lambda x: x.value.item())
				board.make_move(*state_values.action)
	
	stats.append(board.game_state == GameState(-1))

sum(stats), len(stats)
